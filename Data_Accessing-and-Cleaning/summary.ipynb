# %% [markdown]
# # Data Accessing and Cleaning
# ### Data Accessing
# whenever, we get the datasets, and as a Data Analyst, our first goal is to understand the data and :- <br>
# - write the summary for it.
# - we start writing the proper column description.
# - Adding any additional information
#
# ## And now after this we will start Assessment
# ### Types of Assessment
# - Manual
# - Programmable
